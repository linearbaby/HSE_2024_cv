# %%
import ultralytics

# Load a pretrained YOLO model
model = ultralytics.YOLO("ckpt/best_100.pt")
model.metrics = ["mAP50", "mAP50-95", "precision"]

# %%
model.train(
    project="live-scooters-content",
    data="datasets/live-scooters.yaml",
    device="0",
    single_cls=True,
    augment=True,
    shear=25,
    degrees=25,
    epochs=5,
    batch=-1,
    imgsz=640,
    plots=True,
    visualize=True,
    save_period=10,
    cos_lr=True,
    dfl=1.5,
    pose=0.0,
    label_smoothing=0.1,
    translate=0.3,
    mosaic=0.9,
    dropout=0.4,
    seed=0,
)
# Out:
# New https://pypi.org/project/ultralytics/8.2.31 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.29 🚀 Python-3.11.6 torch-2.1.2+cu121 CUDA:0 (NVIDIA GeForce RTX 4070, 12006MiB)
# ...

# %%
# Validate the model
metrics = model.val(data="datasets/surveillance-cam-scooters.yaml")

# Access specific metrics
print(f"mAP50-95: {metrics.box.map}")
print(f"mAP50: {metrics.box.map50}")
print(f"mAP75: {metrics.box.map75}")
print(f"Precision (P): {metrics.box.mp}")
print(f"Recall (R): {metrics.box.mr}")
# Out:
# Ultralytics YOLOv8.2.29 🚀 Python-3.11.6 torch-2.1.2+cu121 CUDA:0 (NVIDIA GeForce RTX 4070, 12006MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients
# val: Scanning /data/notebooks/tracking/datasets/surveillance-cam-scooters-yolo/labels/val.cache... 637 images, 0 backgrounds, 0 corrupt: 100%|██████████| 637/637 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:03<00:00,  4.19it/s]
#                    all        637        741      0.679       0.74      0.738      0.336
# Speed: 0.1ms preprocess, 2.9ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to live-scooters-content/train22
# mAP50-95: 0.33626248285180493
# mAP50: 0.737952262231323
# mAP75: 0.22146364063099716
# Precision (P): 0.6793580895587797
# Recall (R): 0.7395411605937922

# %%
# NOTE: restart required here to free up memory :)

# %%
import ultralytics

# Load a pretrained YOLO model
model = ultralytics.YOLO("live-scooters-content/train2/weights/best.pt")
model.metrics = ["mAP50", "mAP50-95", "precision"]

# %%
model.train(
    project="street-cams-content",
    data="datasets/surveillance-cam-scooters.yaml",
    device="0",
    single_cls=True,
    augment=True,
    shear=0,
    degrees=10,
    epochs=2,
    batch=-1,
    imgsz=640,
    plots=True,
    visualize=True,
    save_period=10,
    cos_lr=True,
    dfl=1.0,
    pose=0.0,
    label_smoothing=0.0,
    translate=0.3,
    mosaic=1.0,
    dropout=0.1,
)
# Out:
# New https://pypi.org/project/ultralytics/8.2.31 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.29 🚀 Python-3.11.6 torch-2.1.2+cu121 CUDA:0 (NVIDIA GeForce RTX 4070, 12006MiB)
# ...

# %%
# Validate the model
metrics = model.val()

# Access specific metrics
print(f"mAP50-95: {metrics.box.map}")
print(f"mAP50: {metrics.box.map50}")
print(f"mAP75: {metrics.box.map75}")
print(f"Precision (P): {metrics.box.mp}")
print(f"Recall (R): {metrics.box.mr}")
# Out:
# Ultralytics YOLOv8.2.29 🚀 Python-3.11.6 torch-2.1.2+cu121 CUDA:0 (NVIDIA GeForce RTX 4070, 12006MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients
# val: Scanning /data/notebooks/tracking/datasets/surveillance-cam-scooters-yolo/labels/val.cache... 637 images, 0 backgrounds, 0 corrupt: 100%|██████████| 637/637 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:03<00:00,  4.28it/s]
#                    all        637        741      0.683      0.722      0.722      0.333
# Speed: 0.1ms preprocess, 3.0ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to street-cams-content/train32
# mAP50-95: 0.33292815343475823
# mAP50: 0.722236219719003
# mAP75: 0.22994580742181914
# Precision (P): 0.6831762963007593
# Recall (R): 0.72168682949552
